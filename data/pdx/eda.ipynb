# %%
import pandas as pd
import numpy as np

# %%
fname = 'PDX_klaegerscan_data_for_ml.zip'
#unzip this file to get the data
import zipfile
with zipfile.ZipFile(fname, 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
#read in the data
data = pd.read_csv('PDX_klaegerscan_data_for_ml.csv', index_col=0)
data.head()
# Out:
#              Treatment                     Treatment.target Treatment.type
# Model
# X1004           BGJ398                                 FGFR         single  \
# X1004           BKM120  PIK3CA,PIK3CB,PIK3CG,PIK3CD,panPI3K         single
# X1004           BYL719                               PIK3CA         single
# X1004           BYL719                               PIK3CA         single
# X1004  BYL719 + LEE011                        PIK3CA,CDK4/6          combo
#
#        BestResponse  Day_BestResponse  BestAvgResponse  Day_BestAvgResponse
# Model
# X1004         -54.3                12            -28.1                   26  \
# X1004          64.6                22             23.7                   11
# X1004          20.0                18              9.3                   11
# X1004          20.0                18              9.3                   11
# X1004         119.0                22             52.6                   11
#
# ...

# %%
#check the first ten columns
data.columns[:20]
# Out:
# Index(['Treatment', 'Treatment.target', 'Treatment.type', 'BestResponse',
#        'Day_BestResponse', 'BestAvgResponse', 'Day_BestAvgResponse',
#        'TimeToDouble', 'Day_Last', 'ResponseCategory', 'NonPD', 'CRorPR',
#        'TumorType', 'RespScaled', 'logSurv', 'logSurvScaled',
#        'cnv_FocalCNScore', 'cnv_A1BG', 'cnv_A1BG-AS1', 'cnv_A1CF'],
#       dtype='object')

# %%
data['TumorType'].value_counts()
# Out:
# TumorType
# CRC      329
# BRCA     303
# PDAC     302
# CM       256
# NSCLC    225
# Name: count, dtype: int64
