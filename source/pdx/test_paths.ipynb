# %%
import pandas as pd

# %%
drug = 'ib'
outcome = 'OS'

# %%
train = pd.read_csv('../../data/pdx_act_mut_cpr.csv', index_col=0)
train.head()
# Out:
#        act_AAK1  act_ABL1  act_ABL1_nonphosphorylated  \
# line
# X1027      1.00         1                        0.68
# X1027      1.00         1                        1.00
# X1027      0.75         1                        0.53
# X1027      0.75         1                        0.53
# X1027      0.75         1                        0.53
#
#        act_ABL1_phosphorylated  act_ABL2  act_ACVR1  act_ACVR1B  act_ACVR2A  \
# line
# X1027                      1.0      1.00        1.0        0.82        0.75
# X1027                      1.0      1.00        1.0        1.00        0.93
# X1027                      0.1      0.96        1.0        0.93        1.00
# X1027                      0.1      0.96        1.0        0.93        1.00
# X1027                      0.1      0.96        1.0        0.93        1.00
#
#        act_ACVR2B  act_ACVRL1  ...  mut_CDKN1A  mut_ROS1  mut_DAXX  mut_TSC2  \
# line                           ...
# ...

# %%
data = pd.read_csv('../../data/crc_ib_mut_act.csv', index_col=0)
data.head()
# Out:
#                    act_AAK1  act_ABL1  act_ABL1_nonphosphorylated  \
# GENIE-DFCI-000971       1.0  0.581644                         1.0
# GENIE-DFCI-001038       1.0  0.581644                         1.0
# GENIE-DFCI-002499       1.0  0.344558                         1.0
# GENIE-DFCI-002507       1.0  0.581644                         1.0
# GENIE-DFCI-002561       1.0  0.581644                         1.0
#
#                    act_ABL1_phosphorylated  act_ABL2  act_ACVR1  act_ACVR1B  \
# GENIE-DFCI-000971                      1.0  1.000000        1.0         1.0
# GENIE-DFCI-001038                      1.0  1.000000        1.0         1.0
# GENIE-DFCI-002499                      1.0  0.505122        1.0         1.0
# GENIE-DFCI-002507                      1.0  1.000000        1.0         1.0
# GENIE-DFCI-002561                      1.0  1.000000        1.0         1.0
#
#                    act_ACVR2A  act_ACVR2B  act_ACVRL1  ...  mut_DAXX  \
# ...
