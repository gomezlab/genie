# %%
# %%
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('--drug', type=str, default='ib')
parser.add_argument('--outcome', type=str, default='OS')

args = parser.parse_args()

drug = args.drug
outcome = args.outcome
# Out:
# usage: ipykernel_launcher.py [-h] [--drug DRUG] [--outcome OUTCOME]
# ipykernel_launcher.py: error: unrecognized arguments: --ip=127.0.0.1 --stdin=9008 --control=9006 --hb=9005 --Session.signature_scheme="hmac-sha256" --Session.key=b"c4898c98-16c4-4036-970f-a251228f6923" --shell=9007 --transport="tcp" --iopub=9009 --f=/home/kchen/.local/share/jupyter/runtime/kernel-v2-12065969ylv7vtIse7K.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
drug_list = ['folfox']
out_list = ['PFS', 'OS']

# %%
res_df = pd.DataFrame()
for drug in drug_list:
    for outcome in out_list:
        data = pd.read_csv('../data/crc_{}_mut_cna_fus_clin.csv'.format(drug), index_col=0)
        y_var = outcome
        data = data.dropna(subset=[y_var])
        #training data is id_institution == 'DFCI' or 'MSKCC', test is 'VICC'
        train = data[data['id_institution'].isin(['VICC', 'MSKCC'])]
        test = data[data['id_institution'] == 'DFCI']

        dtypes = ['mut', 'cna', 'clin', 'fus', 'comb']

        train_dfs = {}
        test_dfs = {}

        for dtype in dtypes:
            if dtype != 'comb':
                train_dfs[dtype] = train[[col for col in data.columns if '{}_'.format(dtype) in col]]
                test_dfs[dtype] = test[[col for col in data.columns if '{}_'.format(dtype) in col]]
            else:
                train_dfs[dtype] = train[[col for col in data.columns if 'mut_' in col or 'cna_' in col or 'clin_' in col]]
                test_dfs[dtype] = test[[col for col in data.columns if 'mut_' in col or 'cna_' in col or 'clin_' in col]]

        
        
        for dtype in dtypes:
            #feature selection using lasso
            lasso = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
            X = train_dfs[dtype]
            y = train[y_var]
            lasso.fit(X, y)
            #get the selected features
            selected = X.columns[np.where(lasso.coef_ != 0)[1]]
            #select the features
            train_dfs[dtype] = train_dfs[dtype][selected]
            test_dfs[dtype] = test_dfs[dtype][selected]
            #train the model
            rf = RandomForestClassifier(n_estimators=1000)
            rf.fit(train_dfs[dtype], y)
            auroc = roc_auc_score(test[y_var], rf.predict_proba(test_dfs[dtype])[:,1])
            #add the results to the dataframe
            # res_df = pd.concat(res_df, pd.DataFrame({'drug': drug, 'outcome': outcome, 'dtype': dtype, 'auroc': auroc}))
            #fix this error -  ValueError: If using all scalar values, you must pass an index
            res_df = pd.concat([res_df, pd.DataFrame({'drug': [drug], 'outcome': [outcome], 'dtype': [dtype], 'auroc': [auroc]})])

# %%
res_df
# Out:
#      drug outcome dtype     auroc
# 0  folfox     PFS   mut  0.544318
# 0  folfox     PFS   cna  0.461857
# 0  folfox     PFS  clin  0.534133
# 0  folfox     PFS   fus  0.500000
# 0  folfox     PFS  comb  0.522234
# 0  folfox      OS   mut  0.505268
# 0  folfox      OS   cna  0.466564
# 0  folfox      OS  clin  0.667774
# 0  folfox      OS   fus  0.500000
# 0  folfox      OS  comb  0.667868

# %%
#find the top performing model overall
res_df.groupby(['drug', 'outcome']).max()
# Out:
#                dtype     auroc
# drug   outcome
# folfox OS        mut  0.689771
#        PFS       mut  0.582891

# %%
data = pd.read_csv('../data/crc_vegf_mut_cna_clin.csv', index_col=0)
data.head()
# Out:
#                   institution
# record_id
# GENIE-DFCI-000147        DFCI  \
# GENIE-DFCI-000233        DFCI
# GENIE-DFCI-000306        DFCI
# GENIE-DFCI-000738        DFCI
# GENIE-DFCI-000946        DFCI
#
#                                                           drugs_list  OS  PFS
# record_id
# GENIE-DFCI-000147  Bevacizumab, Fluorouracil, Irinotecan Hydrochl...   1  1.0  \
# GENIE-DFCI-000233  Bevacizumab, Fluorouracil, Irinotecan Hydrochl...   1  0.0
# GENIE-DFCI-000306  Bevacizumab, Fluorouracil, Leucovorin Calcium,...   1  1.0
# GENIE-DFCI-000738  Bevacizumab, Fluorouracil, Irinotecan Hydrochl...   0  0.0
# GENIE-DFCI-000946                          Bevacizumab, Fluorouracil   1  0.0
#
#                    mut_CDK4  mut_CCND3  mut_CDH1  mut_CDK8  mut_GNAS
# record_id
# GENIE-DFCI-000147         0          0         0         0         0  \
# GENIE-DFCI-000233         0          0         0         0         0
# GENIE-DFCI-000306         0          0         0         0         0
# GENIE-DFCI-000738         0          0         0         0         0
# GENIE-DFCI-000946         0          0         0         0         0
#
#                    mut_PRKAR1A  ...  clin_ca_tx_pre_path_stage
# record_id                       ...
# GENIE-DFCI-000147            0  ...                          0  \
# GENIE-DFCI-000233            0  ...                          1
# GENIE-DFCI-000306            0  ...                          0
# GENIE-DFCI-000738            0  ...                          0
# GENIE-DFCI-000946            0  ...                          0
#
#                    clin_ca_first_dmets1  clin_ca_crc_td  clin_ca_crc_crm
# record_id
# GENIE-DFCI-000147                     5               0                2  \
# GENIE-DFCI-000233                     5               2                2
# GENIE-DFCI-000306                     1               2                2
# GENIE-DFCI-000738                     5               0                2
# GENIE-DFCI-000946                     5               2                3
#
#                    clin_ca_crc_peri_inv  clin_crc_type
# record_id
# GENIE-DFCI-000147                     0              2  \
# GENIE-DFCI-000233                     0              2
# GENIE-DFCI-000306                     0              3
# GENIE-DFCI-000738                     0              3
# GENIE-DFCI-000946                     1              0
#
#                    clin_Histology Category  clin_Histology
# record_id
# GENIE-DFCI-000147                        0               0  \
# GENIE-DFCI-000233                        0               0
# GENIE-DFCI-000306                        0               0
# GENIE-DFCI-000738                        0               1
# GENIE-DFCI-000946                        0               0
#
#                    clin_Derived Grade or Differentiation of Tumor  clin_CEA
# record_id
# GENIE-DFCI-000147                                               1       2.8
# GENIE-DFCI-000233                                               1       1.0
# GENIE-DFCI-000306                                               1       0.7
# GENIE-DFCI-000738                                               1       1.8
# GENIE-DFCI-000946                                               1       5.5
#
# [5 rows x 473 columns]

# %%
data_mut = data[[col for col in data.columns if 'mut_' in col]]
data_cna = data[[col for col in data.columns if 'cna_' in col]]
data_clin = data[[col for col in data.columns if 'clin_' in col]]
os = data['OS']
pfs = data['PFS']
print(data.shape, data_mut.shape, data_cna.shape, data_clin.shape)
# Out:
# (922, 473) (922, 224) (922, 224) (922, 21)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
#get top 20 feature importances and plot as a horizontal bar chart
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.title("Feature importances")
plt.barh(range(20), importances[indices][:20], color="r", align="center")
plt.yticks(range(20), X.columns[indices][:20])
plt.ylim([-1, 20])
plt.savefig('../results/feature_importances.png')
